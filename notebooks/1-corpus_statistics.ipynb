# %% [markdown]
# ### Importing packages

# %%
! pip install -U pandas squarify lxml networkx folderstats
# Out:
# Requirement already up-to-date: pandas in /opt/conda/lib/python3.7/site-packages (1.0.5)
# Requirement already up-to-date: squarify in /opt/conda/lib/python3.7/site-packages (0.4.3)
# Requirement already up-to-date: lxml in /opt/conda/lib/python3.7/site-packages (4.5.2)
# Requirement already up-to-date: networkx in /opt/conda/lib/python3.7/site-packages (2.4)
# Requirement already up-to-date: folderstats in /opt/conda/lib/python3.7/site-packages (0.3.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /opt/conda/lib/python3.7/site-packages (from pandas) (1.17.2)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /opt/conda/lib/python3.7/site-packages (from pandas) (2019.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /opt/conda/lib/python3.7/site-packages (from pandas) (2.8.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from networkx) (4.4.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.12.0)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from networkx.drawing.nx_pydot import graphviz_layout

import xml.etree.ElementTree as ET
from lxml import etree
from bs4 import BeautifulSoup as bs

import squarify

# %% [markdown]
# ### Examining files

# %%
path = '/home/jovyan/shared/C_amc_141/R_amc_3.1_12921/203_vert_spacy_rftt/'

files = []
for r, d, f in os.walk(path):
    for file in f:
        files.append(os.path.join(r, file))

# %%
print(len(files))
for f in files[0:10]:
    print(f)
# Out:
# 175600
# /home/jovyan/shared/C_amc_141/R_amc_3.1_12921/203_vert_spacy_rftt/artikel_/APA/1986/APA_19860220.xml
# /home/jovyan/shared/C_amc_141/R_amc_3.1_12921/203_vert_spacy_rftt/artikel_/APA/1986/APA_19860102.xml
# /home/jovyan/shared/C_amc_141/R_amc_3.1_12921/203_vert_spacy_rftt/artikel_/APA/1986/APA_19860222.xml
# /home/jovyan/shared/C_amc_141/R_amc_3.1_12921/203_vert_spacy_rftt/artikel_/APA/1986/APA_19860103.xml
# /home/jovyan/shared/C_amc_141/R_amc_3.1_12921/203_vert_spacy_rftt/artikel_/APA/1986/APA_19860221.xml
# /home/jovyan/shared/C_amc_141/R_amc_3.1_12921/203_vert_spacy_rftt/artikel_/APA/1986/APA_19860104.xml
# /home/jovyan/shared/C_amc_141/R_amc_3.1_12921/203_vert_spacy_rftt/artikel_/APA/1986/APA_19860223.xml
# /home/jovyan/shared/C_amc_141/R_amc_3.1_12921/203_vert_spacy_rftt/artikel_/APA/1986/APA_19860105.xml
# /home/jovyan/shared/C_amc_141/R_amc_3.1_12921/203_vert_spacy_rftt/artikel_/APA/1986/APA_19860224.xml
# /home/jovyan/shared/C_amc_141/R_amc_3.1_12921/203_vert_spacy_rftt/artikel_/APA/1986/APA_19860106.xml

# %% [markdown]
# [using a pre-generated folderstats csv](https://janakiev.com/blog/python-filesystem-analysis/)

# %%
#!folderstats ~/shared/C_amc_141/ -p -i -v -o ~/AMC_Corpus_Biases/outputs/csv/files_corpus.csv
#!folderstats ~/shared/C_amc_141/R_amc_3.1_12921/ -p -i -v -o ~/AMC_Corpus_Biases/outputs/csv/files_corpus_3.1.csv

# %%
df_files = pd.read_csv('../outputs/csv/files_corpus_3.1.csv')
df_files = df_files[df_files['folder'] == False]
df_files.drop(['id', 'num_files'], axis=1, inplace=True)
df_files.drop(['atime','ctime','mtime'], axis=1, inplace=True)
df_files['path'] = df_files['path'].str.replace('/home/jovyan/shared/C_amc_141/R_amc_3.1_12921/203_vert_spacy_rftt/', '')
df_files['main'] = df_files['path'].str.extract(r'([A-Za-z-_]+)(\/)', expand=False)[0]
df_files['source'] = df_files['path'].str.extract(r'([A-Za-z-_]+)\/([A-Za-z-_]+)(\/)', expand=False)[1]
df_files['year'] = df_files['path'].str.extract(r'([A-Za-z-_]+)\/([A-Za-z-_]+)\/([0-9]{4})', expand=False)[2]
df_files['year'] = pd.to_datetime(df_files['year']).dt.to_period('Y')
df_files['date'] = pd.to_datetime(df_files['name'].str.extract(r'([A-Za-z_]+)([0-9]{8})', 
                                                               expand=False)[1], format='%Y%m%d', errors='coerce')

df_files[['date', 'main', 'source', 'year', 'name', 'size', 'path',]].head()
# Out:
#         date      main source  year          name     size  \
# 0 1986-02-20  artikel_    APA  1986  APA_19860220  6142251
# 1 1986-01-02  artikel_    APA  1986  APA_19860102  3397140
# 2 1986-02-22  artikel_    APA  1986  APA_19860222  3352934
# 3 1986-01-03  artikel_    APA  1986  APA_19860103  3794819
# 4 1986-02-21  artikel_    APA  1986  APA_19860221  5763730
#
#                                  path
# 0  artikel_/APA/1986/APA_19860220.xml
# 1  artikel_/APA/1986/APA_19860102.xml
# 2  artikel_/APA/1986/APA_19860222.xml
# 3  artikel_/APA/1986/APA_19860103.xml
# 4  artikel_/APA/1986/APA_19860221.xml

# %%
df_files.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 175600 entries, 0 to 176739
# Data columns (total 12 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   path       175600 non-null  object
#  1   name       175600 non-null  object
#  2   extension  175600 non-null  object
#  3   size       175600 non-null  int64
#  4   folder     175600 non-null  bool
#  5   depth      175600 non-null  int64
#  6   parent     175600 non-null  int64
#  7   uid        175600 non-null  int64
#  8   main       175600 non-null  object
#  9   source     171457 non-null  object
#  10  year       171457 non-null  period[A-DEC]
#  11  date       175600 non-null  datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), int64(4), object(5), period[A-DEC](1)
# memory usage: 16.2+ MB

# %% [markdown]
# #### Saving pickle

# %%
df_files.to_pickle('../outputs/df_files.pkl')

# %% [markdown]
# ### Showing counts of artikels, magazines and TV:

# %%
with plt.style.context('ggplot'):
    df_files['main'].value_counts().plot(kind='bar',
                                         figsize=(12,8),
                                         color='C1', 
                                         title='Extension Distribution by Count');

# %% [markdown]
# ### Showing sources for all artikels, magazines and TV:
#
# #### by size

# %%
# Group by extension and sum all sizes for each extension
source_sizes = df_files.groupby('source')['size'].sum()

# Sort elements by size
source_sizes = source_sizes.sort_values(ascending=False)

plt.figure(figsize=(16,10))
squarify.plot(sizes=source_sizes.values, 
              label=source_sizes.index.values)

plt.title('Source Treemap by Size')
plt.axis('off');

# %% [markdown]
# ### Showing sources for artikels only:
#
# #### by size

# %%
# Group by extension and sum all sizes for each extension
source_sizes = df_files[df_files['main'] == 'artikel_'].groupby('source')['size'].sum()

# Sort elements by size
source_sizes = source_sizes.sort_values(ascending=False)

plt.figure(figsize=(16,10))
squarify.plot(sizes=source_sizes.values, 
              label=source_sizes.index.values)

plt.title('Source Treemap by Size')
plt.axis('off');

# %% [markdown]
# #### by count

# %%
with plt.style.context('ggplot'):
    df_files['source'][df_files['main'] == 'artikel_'].value_counts().plot(kind='bar',
                                                                           figsize=(12,8),
                                                                           color='C1',
                                                                           title='Extension Distribution by Count');

# %% [markdown]
# ### Temporal evolution of all artikel:

# %%
count_by_year = df_files['year'].value_counts(ascending=True)
plt.style.context('ggplot')
count_by_year.plot(kind='bar',
                   figsize=(12,8),
                   color='C2',
                   title='Yearly evolution - count');
